# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'data_quality_report.txt',
#  'part1-database-etl',
#  'Part2-nosql',
#  'part3-datawarehouse']

# %%
os.listdir('data')
# Out:
# ['.ipynb_checkpoints',
#  'Customers.csv',
#  'customers_cleaned.csv',
#  'products_cleaned.csv',
#  'products_raw.csv',
#  'sales_cleaned.csv',
#  'sales_raw.csv']

# %%
import pandas as pd

import os
fnames = []
fpaths = []
for dirname, _, filenames in os.walk(r'C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data'):
    for filename in filenames:
        fnames.append(filename.split('.')[0])
        fpaths.append(os.path.join(dirname, filename))
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\Customers.csv
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\customers_cleaned.csv
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\products_cleaned.csv
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\products_raw.csv
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\sales_cleaned.csv
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\sales_raw.csv
# C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data\.ipynb_checkpoints\customers_cleaned-checkpoint.csv

# %%
fpath = r'C:\Users\ishaan karwayun\OneDrive - Symbiosis International University\Desktop\BITSOM\studentID-fleximart-data-architecture\data'
customers_raw_df = pd.read_csv(os.path.join(fpath,'Customers.csv'),na_values = r'/N')
products_raw_df = pd.read_csv(os.path.join(fpath,'products_raw.csv'),na_values = r'/N')
sales_raw_df = pd.read_csv(os.path.join(fpath,'sales_raw.csv'),na_values = r'/N')

# %%
customers.head()
# Out:
#   customer_id first_name last_name                     email           phone  \
# 0        C001      Rahul    Sharma    rahul.sharma@gmail.com      9876543210
# 1        C002      Priya     Patel     priya.patel@yahoo.com  +91-9988776655
# 2        C003       Amit     Kumar                       NaN      9765432109
# 3        C004      Sneha     Reddy     sneha.reddy@gmail.com      9123456789
# 4        C005     Vikram     Singh  vikram.singh@outlook.com     09988112233
#
#         city registration_date
# 0  Bangalore        2023-01-15
# 1     Mumbai        2023-02-20
# 2      Delhi        2023-03-10
# 3  Hyderabad        15/04/2023
# 4    Chennai        2023-05-22

# %%
#creating copies 
customers = customers_raw_df.copy()
products = products_raw_df.copy()
sales = sales_raw_df.copy()

# %%
#handling missing email values
missing_email_mask = customers['email'].isna() | (customers['email'].str.strip() == '')
customers.loc[missing_email_mask, 'email'] = (
    'unknown_' +
    customers.loc[missing_email_mask, 'customer_id'] +
    '@fleximart.com'
)

# %%
# Dropping Duplicates
customers = customers.drop_duplicates()

# %%
#Organising Phone column
customers['phone'].astype(str).unique()
customers['phone'].str.contains(r'[^0-9+]', regex=True).sum()
# Out:
# np.int64(2)

# %%
customers['phone'] = customers['phone'].astype(str).str.replace(r'\D', '', regex = True)
customers['phone'] = customers['phone'].str.lstrip('0')
customers['phone'] = customers['phone'].apply(lambda x: '+91' + x if len(x) == 10 else '+' + x if x.startswith('91') else x)

# %%
customers['registration_date'] = customers['registration_date'].str.replace('/', '-')
from datetime import datetime
def parse_mixed_date(x):
    for fmt in ("%d-%m-%Y", "%Y-%m-%d", "%m-%d-%Y"):
        try:
            return datetime.strptime(x, fmt)
        except:
            continue
    return x  # keep original if it doesn't match any
customers['registration_date'] = customers['registration_date'].apply(parse_mixed_date)

# %%
customers['city'] = customers['city'].str.strip()
customers['city'] = customers['city'].str.lower()

# %%
customers
# Out:
#    customer_id first_name last_name                       email  \
# 0         C001      Rahul    Sharma      rahul.sharma@gmail.com
# 1         C002      Priya     Patel       priya.patel@yahoo.com
# 2         C003       Amit     Kumar  unknown_C003@fleximart.com
# 3         C004      Sneha     Reddy       sneha.reddy@gmail.com
# 4         C005     Vikram     Singh    vikram.singh@outlook.com
# 5         C006     Anjali     Mehta      anjali.mehta@gmail.com
# 6         C007       Ravi     Verma  unknown_C007@fleximart.com
# 7         C008      Pooja      Iyer        pooja.iyer@gmail.com
# 8         C009    Karthik      Nair      karthik.nair@yahoo.com
# 9         C010      Deepa     Gupta       deepa.gupta@gmail.com
# 11        C011      Arjun       Rao         arjun.rao@gmail.com
# 12        C012    Lakshmi  Krishnan  unknown_C012@fleximart.com
# 13        C013     Suresh     Patel    suresh.patel@outlook.com
# 14        C014       Neha      Shah         neha.shah@gmail.com
# 15        C015     Manish     Joshi      manish.joshi@yahoo.com
# 16        C016      Divya     Menon       divya.menon@gmail.com
# 17        C017     Rajesh     Kumar      rajesh.kumar@gmail.com
# 18        C018      Kavya     Reddy  unknown_C018@fleximart.com
# 19        C019       Arun    Pillai     arun.pillai@outlook.com
# 20        C020      Swati     Desai       swati.desai@gmail.com
# 21        C021     Nikhil      Bose       nikhil.bose@gmail.com
# 22        C022   Priyanka      Jain     priyanka.jain@yahoo.com
# 23        C023      Rohit    Kapoor  unknown_C023@fleximart.com
# 24        C024      Meera   Nambiar     meera.nambiar@gmail.com
# 25        C025     Sanjay   Agarwal    sanjay.agarwal@gmail.com
#
#             phone        city registration_date
# 0   +919876543210   bangalore        2023-01-15
# 1   +919988776655      mumbai        2023-02-20
# 2   +919765432109       delhi        2023-03-10
# 3   +919123456789   hyderabad        2023-04-15
# 4   +919988112233     chennai        2023-05-22
# 5   +919876543210   bangalore        2023-06-18
# 6   +919876501234        pune        2023-07-25
# 7   +919123456780   bangalore        2023-08-15
# 8   +919988776644       kochi        2023-09-30
# 9   +919871234567       delhi        2023-10-12
# 11  +919876509876   hyderabad        2023-11-05
# 12  +919988001122     chennai        2023-12-01
# 13  +919123409876      mumbai        2024-01-08
# 14  +919876543221   ahmedabad        2024-01-15
# 15  +919988776611      jaipur        2024-01-20
# 16  +919123456701   bangalore        2024-02-05
# 17  +919876123450       delhi        2024-02-12
# 18  +919988112200   hyderabad        2024-02-18
# 19  +919876543298       kochi        2024-02-25
# 20  +919123456712        pune        2024-03-01
# 21  +919988776600     kolkata        2024-03-10
# 22  +919876543287      indore        2024-03-15
# 23  +919988112211  chandigarh        2024-03-20
# 24  +919123456723  trivandrum        2024-03-25
# 25  +919876543276     lucknow        2024-03-28

# %%
# Organising Products
products['category'] = products['category'].str.strip()
products['category'] = products['category'].str.lower()

# %%
products['price'] = products['price'].fillna(0).astype(int)

# %%
category_price = products.groupby('category')['price'].agg('mean','median').reset_index().round(2)
category_price
# Out:
#       category     price
# 0  electronics  24277.00
# 1      fashion   2827.71
# 2    groceries    529.75

# %%
products['price'].replace(0, pd.NA)

# %%
#filling missing values with categorical means
products['price'] = products.groupby('category')['price'].transform(
    lambda x: x.where(x != 0, x.median())
).astype(int)

# %%
#filling missing stock qty with 0
products['stock_quantity'] = products['stock_quantity'].fillna(0).astype(int)

# %%
products
# Out:
#    product_id         product_name     category  price  stock_quantity
# 0        P001   Samsung Galaxy S21  electronics  45999             150
# 1        P002   Nike Running Shoes      fashion   3499              80
# 2        P003    Apple MacBook Pro  electronics  12999              45
# 3        P004         Levi's Jeans      fashion   2999             120
# 4        P005      Sony Headphones  electronics   1999             200
# 5        P006      Organic Almonds    groceries    899               0
# 6        P007            HP Laptop  electronics  52999              60
# 7        P008       Adidas T-Shirt      fashion   1299             150
# 8        P009     Basmati Rice 5kg    groceries    650             300
# 9        P010         OnePlus Nord  electronics  12999              95
# 10       P011        Puma Sneakers      fashion   4599              70
# 11       P012  Dell Monitor 24inch  electronics  12999              40
# 12       P013       Woodland Shoes      fashion   5499              55
# 13       P014            iPhone 13  electronics  69999              80
# 14       P015   Organic Honey 500g    groceries    450             200
# 15       P016    Samsung TV 43inch  electronics  32999              35
# 16       P017            H&M Shirt      fashion   2999              90
# 17       P018       Masoor Dal 1kg    groceries    120             500
# 18       P019         Boat Earbuds  electronics   1499             250
# 19       P020    Reebok Trackpants      fashion   1899             110

# %%
# Cleaning sales data
sales['transaction_date']=sales_raw_df['transaction_date']

# %%
sales['transaction_date'] = sales['transaction_date'].astype(str).str.replace('/','-')
sales['transaction_date'] = sales['transaction_date'].apply(parse_mixed_date)
sales['unit_price'] = sales['unit_price'].astype(int)

# %%
sales = sales.drop_duplicates()

# %%
report = f"""
CUSTOMERS
Records processed: {len(customers_raw_df)}
Duplicates removed: {customers_raw_df.duplicated().sum()}
Missing values handled: {customers_raw_df['email'].isna().sum()}
Records loaded: {len(customers)}

PRODUCTS
Records processed: {len(products_raw_df)}
Duplicates removed: {products_raw_df.duplicated().sum()}
Missing values handled: {products_raw_df.isna().sum()}
Records loaded: {len(products)}

SALES
Records processed: {len(sales_raw_df)}
Duplicates removed: {sales_raw_df.duplicated().sum()}
Missing values handled: {sales_raw_df.isna().sum()}
Records loaded: {len(sales)}
"""

# %%
with open("data_quality_report.txt", "w") as f:
    f.write(report)

# %%
products_raw_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.to_csv("data/customers_cleaned.csv", index=False)
products.to_csv("data/products_cleaned.csv", index=False)
sales.to_csv("data/sales_cleaned.csv", index=False)

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\ishaan karwayun\.anaconda\anagenda\lib\site-packages (9.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="ONZIbonzi1234",  # replace with your MySQL password
    database="fleximart"
)
cursor = conn.cursor()

# %%
customers
# Out:
#    customer_id first_name last_name                       email  \
# 0         C001      Rahul    Sharma      rahul.sharma@gmail.com
# 1         C002      Priya     Patel       priya.patel@yahoo.com
# 2         C003       Amit     Kumar  unknown_C003@fleximart.com
# 3         C004      Sneha     Reddy       sneha.reddy@gmail.com
# 4         C005     Vikram     Singh    vikram.singh@outlook.com
# 5         C006     Anjali     Mehta      anjali.mehta@gmail.com
# 6         C007       Ravi     Verma  unknown_C007@fleximart.com
# 7         C008      Pooja      Iyer        pooja.iyer@gmail.com
# 8         C009    Karthik      Nair      karthik.nair@yahoo.com
# 9         C010      Deepa     Gupta       deepa.gupta@gmail.com
# 11        C011      Arjun       Rao         arjun.rao@gmail.com
# 12        C012    Lakshmi  Krishnan  unknown_C012@fleximart.com
# 13        C013     Suresh     Patel    suresh.patel@outlook.com
# 14        C014       Neha      Shah         neha.shah@gmail.com
# 15        C015     Manish     Joshi      manish.joshi@yahoo.com
# 16        C016      Divya     Menon       divya.menon@gmail.com
# 17        C017     Rajesh     Kumar      rajesh.kumar@gmail.com
# 18        C018      Kavya     Reddy  unknown_C018@fleximart.com
# 19        C019       Arun    Pillai     arun.pillai@outlook.com
# 20        C020      Swati     Desai       swati.desai@gmail.com
# 21        C021     Nikhil      Bose       nikhil.bose@gmail.com
# 22        C022   Priyanka      Jain     priyanka.jain@yahoo.com
# 23        C023      Rohit    Kapoor  unknown_C023@fleximart.com
# 24        C024      Meera   Nambiar     meera.nambiar@gmail.com
# 25        C025     Sanjay   Agarwal    sanjay.agarwal@gmail.com
#
#             phone        city registration_date
# 0   +919876543210   bangalore        2023-01-15
# 1   +919988776655      mumbai        2023-02-20
# 2   +919765432109       delhi        2023-03-10
# 3   +919123456789   hyderabad        2023-04-15
# 4   +919988112233     chennai        2023-05-22
# 5   +919876543210   bangalore        2023-06-18
# 6   +919876501234        pune        2023-07-25
# 7   +919123456780   bangalore        2023-08-15
# 8   +919988776644       kochi        2023-09-30
# 9   +919871234567       delhi        2023-10-12
# 11  +919876509876   hyderabad        2023-11-05
# 12  +919988001122     chennai        2023-12-01
# 13  +919123409876      mumbai        2024-01-08
# 14  +919876543221   ahmedabad        2024-01-15
# 15  +919988776611      jaipur        2024-01-20
# 16  +919123456701   bangalore        2024-02-05
# 17  +919876123450       delhi        2024-02-12
# 18  +919988112200   hyderabad        2024-02-18
# 19  +919876543298       kochi        2024-02-25
# 20  +919123456712        pune        2024-03-01
# 21  +919988776600     kolkata        2024-03-10
# 22  +919876543287      indore        2024-03-15
# 23  +919988112211  chandigarh        2024-03-20
# 24  +919123456723  trivandrum        2024-03-25
# 25  +919876543276     lucknow        2024-03-28

# %%
# Insert into MySQL
for _, row in customers.iterrows():
    try:
        cursor.execute("""
            INSERT INTO customers
            (first_name, last_name, email, phone, city, registration_date)
            VALUES (%s,%s,%s,%s,%s,%s)
        """, tuple(row[['first_name','last_name','email','phone','city','registration_date']]))
        report['customers']['loaded'] += 1
    except Exception as e:
        print("Customer insert failed:", e)

conn.commit()
# Out:
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'
# Customer insert failed: string indices must be integers, not 'str'

# %%
# inserting data in products
for _, row in products.iterrows():
    try:
        cursor.execute("""
            INSERT INTO products
            (product_name, category, price, stock_quantity)
            VALUES (%s,%s,%s,%s)
        """, tuple(row[['product_name','category','price','stock_quantity']]))
        report['products']['loaded'] += 1
    except Exception as e:
        print("products insert failed:", e)

conn.commit()
# Out:
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'
# products insert failed: string indices must be integers, not 'str'

# %%
for _, row in sales.iterrows():
    try:
        cursor.execute("""
            INSERT INTO orders
            (customer_id,order_date,total_amount, status)
            VALUES (%s,%s,%s,%s)
        """, tuple(row[['customer_sk','transaction_date','subtotal','status']]))
    except Exception as e:
        print("sales insert failed:", e)

conn.commit()

# %%
sales.head()
# Out:
#   transaction_id customer_id product_id  quantity  unit_price  \
# 0           T001        C001       P001         1       45999
# 1           T002        C002       P004         2        2999
# 2           T003        C003       P007         1       52999
# 3           T004         NaN       P002         1        3499
# 4           T005        C005       P009         3         650
#
#   transaction_date     status
# 0       2024-01-15  Completed
# 1       2024-01-16  Completed
# 2       2024-01-15  Completed
# 3       2024-01-18    Pending
# 4       2024-01-20  Completed

# %% [raw]
# CREATE TABLE order_items (
#     order_item_id INT PRIMARY KEY AUTO_INCREMENT,
#     order_id INT NOT NULL,
#     product_id INT NOT NULL,
#     quantity INT NOT NULL,
#     unit_price DECIMAL(10,2) NOT NULL,
#     subtotal DECIMAL(10,2) NOT NULL,
#     FOREIGN KEY (order_id) REFERENCES orders(order_id),
#     FOREIGN KEY (product_id) REFERENCES products(product_id)

# %%
sales['subtotal'] = sales['quantity'] * sales['unit_price']

# %%
sales
# Out:
#    transaction_id customer_id product_id  quantity  unit_price  \
# 0            T001        C001       P001         1       45999
# 1            T002        C002       P004         2        2999
# 2            T003        C003       P007         1       52999
# 3            T004         NaN       P002         1        3499
# 4            T005        C005       P009         3         650
# 5            T006        C006       P012         1       12999
# 6            T007        C007       P005         2        1999
# 7            T008        C008        NaN         1        1299
# 8            T009        C009       P011         1        4599
# 9            T010        C010       P006         5         899
# 11           T011        C011       P014         1       69999
# 12           T012        C012       P003         1       52999
# 13           T013        C013       P015         3         450
# 14           T014        C014       P019         2        1499
# 15           T015        C015       P008         3        1299
# 16           T016         NaN       P013         1        5499
# 17           T017        C017       P016         1       32999
# 18           T018        C018       P020         2        1899
# 19           T019        C019       P018        10         120
# 20           T020        C020       P010         1       45999
# 21           T021        C021       P017         2        2999
# 22           T022        C002       P001         1       45999
# 23           T023        C003       P019         3        1499
# 24           T024        C004       P009         5         650
# 25           T025        C005        NaN         1        1999
# 26           T026        C006       P011         1        4599
# 27           T027        C007       P002         2        3499
# 28           T028        C008       P015         4         450
# 29           T029        C009       P007         1       52999
# 30           T030         NaN       P004         3        2999
# 31           T031        C011       P012         1       12999
# 32           T032        C012       P016         1       32999
# 33           T033        C013       P005         2        1999
# 34           T034        C014       P008         2        1299
# 35           T035        C015       P018         8         120
# 36           T036        C016       P014         1       69999
# 37           T037        C017       P006         4         899
# 38           T038        C018       P020         1        1899
# 39           T039        C019       P019         2        1499
# 40           T040        C020       P013         1        5499
#
#    transaction_date     status  subtotal
# 0        2024-01-15  Completed     45999
# 1        2024-01-16  Completed      5998
# 2        2024-01-15  Completed     52999
# 3        2024-01-18    Pending      3499
# 4        2024-01-20  Completed      1950
# 5        2024-01-22  Completed     12999
# 6        2024-01-23  Completed      3998
# 7        2024-01-25  Completed      1299
# 8        2024-01-28  Cancelled      4599
# 9        2024-02-01  Completed      4495
# 11       2024-02-02  Completed     69999
# 12       2024-02-05  Completed     52999
# 13       2024-02-08  Completed      1350
# 14       2024-10-02  Completed      2998
# 15       2024-02-12  Completed      3897
# 16       2024-02-15    Pending      5499
# 17       2024-02-18  Completed     32999
# 18       2024-02-20  Completed      3798
# 19       2024-02-22  Completed      1200
# 20       2024-02-25  Completed     45999
# 21       2024-02-28  Completed      5998
# 22       2024-03-01  Completed     45999
# 23       2024-02-03  Completed      4497
# 24       2024-03-05  Completed      3250
# 25       2024-03-08  Completed      1999
# 26       2024-03-10  Completed      4599
# 27       2024-12-03  Completed      6998
# 28       2024-03-15  Completed      1800
# 29       2024-03-18  Completed     52999
# 30       2024-03-20    Pending      8997
# 31       2024-03-22  Completed     12999
# 32       2024-03-25  Completed     32999
# 33       2024-03-28  Completed      3998
# 34       2024-03-30  Completed      2598
# 35       2024-01-04  Completed       960
# 36       2024-04-03  Completed     69999
# 37       2024-04-05  Completed      3596
# 38       2024-08-04  Completed      1899
# 39       2024-04-10  Completed      2998
# 40       2024-04-12  Completed      5499

# %%
# calling sk customer_id from sql
cursor.execute("""
SELECT customer_id, email, first_name, last_name
FROM customers
""")
rows = cursor.fetchall()

# %%
# creating SQL_customers 
sql_customers = pd.DataFrame(rows, columns=['customer_id', 'email', 'first_name', 'last_name']
)

# %%
# Mapping customer_sk with Customer Ids
customers['customer_sk'] = sql_customers['customer_id'].values

# %%
customers['raw_customer_id'] = customers['customer_id']
customers = customers.drop('customer_id',axis = 1)

# %%
#mapping old customer_id 
customer_map = dict(
    zip(customers['raw_customer_id'], customers['customer_sk'])
)

# %%
# Mapping customer ID
sales['customer_sk'] = sales['customer_id'].map(customer_map)
# Out:
# C:\Users\ishaan karwayun\AppData\Local\Temp\ipykernel_23796\4040543486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['customer_sk'] = sales['customer_id'].map(customer_map)

# %%
sales = sales.dropna(subset =['customer_id'])

# %%
#converting the column to be inserted
sales['customer_sk'] = sales['customer_sk'].astype(int)
# Out:
#    transaction_id customer_id product_id  quantity  unit_price  \
# 0            T001        C001       P001         1       45999
# 1            T002        C002       P004         2        2999
# 2            T003        C003       P007         1       52999
# 4            T005        C005       P009         3         650
# 5            T006        C006       P012         1       12999
# 6            T007        C007       P005         2        1999
# 7            T008        C008        NaN         1        1299
# 8            T009        C009       P011         1        4599
# 9            T010        C010       P006         5         899
# 11           T011        C011       P014         1       69999
# 12           T012        C012       P003         1       52999
# 13           T013        C013       P015         3         450
# 14           T014        C014       P019         2        1499
# 15           T015        C015       P008         3        1299
# 17           T017        C017       P016         1       32999
# 18           T018        C018       P020         2        1899
# 19           T019        C019       P018        10         120
# 20           T020        C020       P010         1       45999
# 21           T021        C021       P017         2        2999
# 22           T022        C002       P001         1       45999
# 23           T023        C003       P019         3        1499
# 24           T024        C004       P009         5         650
# 25           T025        C005        NaN         1        1999
# 26           T026        C006       P011         1        4599
# 27           T027        C007       P002         2        3499
# 28           T028        C008       P015         4         450
# 29           T029        C009       P007         1       52999
# 31           T031        C011       P012         1       12999
# 32           T032        C012       P016         1       32999
# 33           T033        C013       P005         2        1999
# 34           T034        C014       P008         2        1299
# 35           T035        C015       P018         8         120
# 36           T036        C016       P014         1       69999
# 37           T037        C017       P006         4         899
# 38           T038        C018       P020         1        1899
# 39           T039        C019       P019         2        1499
# 40           T040        C020       P013         1        5499
#
#    transaction_date     status  customer_sk
# 0        2024-01-15  Completed            1
# 1        2024-01-16  Completed            2
# 2        2024-01-15  Completed            3
# 4        2024-01-20  Completed            5
# 5        2024-01-22  Completed            6
# 6        2024-01-23  Completed            7
# 7        2024-01-25  Completed            8
# 8        2024-01-28  Cancelled            9
# 9        2024-02-01  Completed           10
# 11       2024-02-02  Completed           11
# 12       2024-02-05  Completed           12
# 13       2024-02-08  Completed           13
# 14       2024-10-02  Completed           14
# 15       2024-02-12  Completed           15
# 17       2024-02-18  Completed           17
# 18       2024-02-20  Completed           18
# 19       2024-02-22  Completed           19
# 20       2024-02-25  Completed           20
# 21       2024-02-28  Completed           21
# 22       2024-03-01  Completed            2
# 23       2024-02-03  Completed            3
# 24       2024-03-05  Completed            4
# 25       2024-03-08  Completed            5
# 26       2024-03-10  Completed            6
# 27       2024-12-03  Completed            7
# 28       2024-03-15  Completed            8
# 29       2024-03-18  Completed            9
# 31       2024-03-22  Completed           11
# 32       2024-03-25  Completed           12
# 33       2024-03-28  Completed           13
# 34       2024-03-30  Completed           14
# 35       2024-01-04  Completed           15
# 36       2024-04-03  Completed           16
# 37       2024-04-05  Completed           17
# 38       2024-08-04  Completed           18
# 39       2024-04-10  Completed           19
# 40       2024-04-12  Completed           20

# %%
#retrieving order data from sql
cursor.execute("""
SELECT order_id, customer_id, order_date, status
FROM orders
""")
rows = cursor.fetchall()

# %%
# inserting data into a table
sql_orders =  pd.DataFrame(rows, columns=['order_id', 'customer_id', 'order_date', 'state'])

# %%
#inserting order_id into sales
sales['order_id'] = sql_orders['order_id']
# Out:
# C:\Users\ishaan karwayun\AppData\Local\Temp\ipykernel_45816\765141022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['order_id'] = sql_orders['order_id']

# %%
sales = sales.dropna(subset=['product_id'])

# %%
#retrieving products data from sql
cursor.execute("""
SELECT *
FROM products
""")
product_rows = cursor.fetchall()

# %%
sql_products = pd.DataFrame(product_rows, columns=['product_id', 'product_name', 'category ', 'price ','stock_quantity'])

# %%
products['product_sk'] = sql_products['product_id']

# %%
# mapping productid with SK to be inserted into sales data
product_map = dict(zip(products['product_id'],
                        products['product_sk']))

# %%
#maping sales product id 
sales['product_sk'] = sales['product_id'].map(product_map)
# Out:
# C:\Users\ishaan karwayun\AppData\Local\Temp\ipykernel_23796\3221493123.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['product_sk'] = sales['product_id'].map(product_map)

# %%
sales = sales.dropna(subset = ['product_sk'])

# %%
sales['product_sk'] = sales['product_sk'].astype(int)
# Out:
# C:\Users\ishaan karwayun\AppData\Local\Temp\ipykernel_23796\598957504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['product_sk'] = sales['product_sk'].astype(int)

# %%
#calling order sk from sql
cursor.execute("""
select * from orders """)
order_rows = cursor.fetchall()

# %%
sql_orders = pd.DataFrame(order_rows,columns = ['order_id','customer_id','order_date','total_amount','status'])

# %%
sales['order_sk'] = sql_orders['order_id']
# Out:
# C:\Users\ishaan karwayun\AppData\Local\Temp\ipykernel_23796\2768416287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['order_sk'] = sql_orders['order_id']

# %%
# Mapping customer Id with order ID to create a mapping that can be used to map Order;s customer Id with order ID
order_map = dict(zip(sql_orders['customer_id'], sql_orders['order_id']))

# %%
sales['order_sk'] = sales['customer_sk'].map(order_map)
# Out:
# C:\Users\ishaan karwayun\AppData\Local\Temp\ipykernel_23796\739977595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['order_sk'] = sales['customer_sk'].map(order_map)

# %%
for _, row in sales.iterrows():
    try:
        cursor.execute("""
            INSERT INTO order_items
            (order_id,product_id,quantity,unit_price,subtotal)
            VALUES (%s,%s,%s,%s,%s)
        """, tuple(row[['order_sk','product_sk','quantity','unit_price','subtotal']]))
    except Exception as e:
        print("sales insert failed:", e)

conn.commit()
